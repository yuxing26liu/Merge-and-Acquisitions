# %%
# 1. Auto-reload every time you save dcf3.py or synergy_model.py
# %load_ext autoreload
# %autoreload 2

# 2. Import your two modules
from dcf3         import DCFModel, DCFArgs
from synergy_model import SynergyModel

# 3. Instantiate your DCF model with notebook-friendly args
args     = DCFArgs(ticker="AAPL")
base_dcf = DCFModel(args.ticker, args)

# 4. Print your baseline valuation
print("Baseline Implied Price:  ", f"${base_dcf.ImpliedPrice:,.2f}")
print("Baseline Margin of Safety:", f"{(base_dcf.ImpliedPrice - base_dcf.price)/base_dcf.price: .2%}")

# 5. Hook up your synergy engine
syncer       = SynergyModel(base_dcf)
enhanced_dcf = syncer.apply_synergies(
    cost_savings_pct=0.10,     # e.g. 10% opex cut
    revenue_boost_pct=0.05,    # e.g. 5% rev uplift
    phase_in_years=3,          # roll in over 3 years
    new_debt_ratio=0.40        # if financing 40% of deal with debt
)

# 6. Compare valuations
print("\nWith Synergies Implied Price:  ",
      f"${enhanced_dcf.ImpliedPrice:,.2f}")
print("With Synergies Margin of Safety:",
      f"{(enhanced_dcf.ImpliedPrice - base_dcf.price)/base_dcf.price: .2%}")
# Out:
# Baseline Implied Price:   $143.34
# Baseline Margin of Safety: -31.35%
#
# With Synergies Implied Price:   $176.25
# With Synergies Margin of Safety: -15.58%

# %%
import os
import pandas as pd

# Path to the folder containing CSV files (adjust if needed)
data_folder = '.'

# Loop through files in the folder
for filename in os.listdir(data_folder):
    if filename.endswith('.csv'):
        file_path = os.path.join(data_folder, filename)
        try:
            df = pd.read_csv(file_path)
            print(f"\n{'='*60}")
            print(f"📁 File: {filename}")
            print(f"📊 Shape: {df.shape[0]} rows × {df.shape[1]} columns")
            print("🧾 Columns:", list(df.columns))
            print("🔍 Preview:")
            print(df.head(), "\n")
        except Exception as e:
            print(f"❌ Could not load {filename}: {e}")
# Out:
# ============================================================
# 📁 File: addition.csv
# 📊 Shape: 2213 rows × 4 columns
# 🧾 Columns: ['content', 'month_str', 'year_str', 'value']
# 🔍 Preview:
#         content month_str  year_str  value
# 0  Acquisitions   1960-01      1960      1
# 1  Acquisitions   1966-11      1966      1
# 2  Acquisitions   1967-04      1967      1
# 3  Acquisitions   1972-01      1972      1
# 4  Acquisitions   1973-01      1973      1
#
#
# ============================================================
# 📁 File: Founders and Board Members.csv
# 📊 Shape: 382 rows × 5 columns
# 🧾 Columns: ['Name', 'CrunchBase Profile', 'Role', 'Companies', 'Image']
# 🔍 Preview:
#                     Name                                 CrunchBase Profile  \
# 0     Hans-Werner Hector    http://de.wikipedia.org/wiki/Hans-Werner_Hector
# 1            Akio Morita           http://en.wikipedia.org/wiki/Akio_Morita
# 2  Alexander Graham Bell  http://en.wikipedia.org/wiki/Alexander_Graham_...
# 3         Andrew Viterbi        http://en.wikipedia.org/wiki/Andrew_Viterbi
# 4              Bob Miner             http://en.wikipedia.org/wiki/Bob_Miner
#
#       Role Companies                                              Image
# 0  Founder       SAP  http://images.forbes.com/media/lists/10/2006/4...
# 1  Founder      Sony       http://www.adeptis.ru/vinci/akio_morita3.jpg
# 2  Founder      AT&T  https://upload.wikimedia.org/wikipedia/commons...
# 3  Founder  Qualcomm  https://alum.mit.edu/sites/default/files/migra...
# 4  Founder    Oracle  https://upload.wikimedia.org/wikipedia/commons...
#
#
# ============================================================
# 📁 File: Acquiring Tech Companies.csv
# 📊 Shape: 36 rows × 23 columns
# 🧾 Columns: ['Acquiring Company', 'CrunchBase Profile', 'Image', 'Tagline', 'Market Categories', 'Year Founded', 'IPO', 'Founders', 'Number of Employees', 'Number of Employees (year of last update)', 'Total Funding ($)', 'Number of Acquisitions', 'Board Members', 'Address (HQ)', 'City (HQ)', 'State / Region (HQ)', 'Country (HQ)', 'Description', 'Homepage', 'Twitter', 'Acquired Companies', 'Acquisitions ID', 'API']
# 🔍 Preview:
#   Acquiring Company                             CrunchBase Profile  \
# 0             Adobe  www.crunchbase.com/organization/adobe-systems
# 1            Amazon         www.crunchbase.com/organization/amazon
# 2               AOL            www.crunchbase.com/organization/aol
# 3             Apple          www.crunchbase.com/organization/apple
# 4              AT&T           www.crunchbase.com/organization/at-t
#
#                                                Image  \
# 0  http://a2.images.crunchbase.com/image/upload/c...
# 1  http://a4.images.crunchbase.com/image/upload/c...
# 2  http://a5.images.crunchbase.com/image/upload/c...
# 3  http://a4.images.crunchbase.com/image/upload/c...
# 4  http://a4.images.crunchbase.com/image/upload/c...
#
#                                              Tagline  \
# 0  Adobe is an American multinational computer so...
# 1  Amazon is an international e-commerce company ...
# 2  AOL is a Brand company committed to innovating...
# 3  Apple is a multinational corporation that desi...
# 4  AT&T provides telecommunications services such...
#
#                                    Market Categories  Year Founded   IPO  \
# 0  Photo Editing, Design, Creative, Software, Ima...          1982  1986
# 1  Groceries, Consumer Goods, Crowdsourcing, E-Co...          1994  1997
# 2  News, Advertising Platforms, Content Creators,...          1985  2009
# 3  Computers, Consumer Electronics, Hardware + So...          1976  1980
# 4                                             Mobile          2000  1983
#
#                                   Founders Number of Employees  \
# 0            John Warnock, Charles Geschke              11,144
# 1                               Jeff Bezos             132,600
# 2      Marc Seriff, Steve Case, Jim Kimsey               5,600
# 3  Steve Jobs, Ronald Wayne, Steve Wozniak              98,000
# 4                    Alexander Graham Bell             246,740
#
#    Number of Employees (year of last update)  ...  \
# 0                                     2012.0  ...
# 1                                     2014.0  ...
# 2                                     2012.0  ...
# 3                                     2014.0  ...
# 4                                     2013.0  ...
#
#                                         Address (HQ)      City (HQ)  \
# 0                San Jose, California, United States       San Jose
# 1              1200 12th Ave, Seattle, WA 98144, USA        Seattle
# 2  770 Broadway, New York City, New York, United ...  New York City
# 3  1 Infinite Loop, Cupertino, California, United...      Cupertino
# 4      208 S. Akard St, Dallas, Texas, United States         Dallas
#
#   State / Region (HQ)   Country (HQ)  \
# 0          California  United States
# 1          Washington  United States
# 2            New York  United States
# 3          California  United States
# 4               Texas  United States
#
#                                          Description              Homepage  \
# 0  Adobe Systems is an American multinational com...  http://www.adobe.com
# 1  Amazon.com is an American international e-comm...     http://amazon.com
# 2  AOL is a global advertising-supported Web comp...    http://www.aol.com
# 3  Apple is an American multinational corporation...  http://www.apple.com
# 4  AT&T Inc. AT&T is a holding company. AT&T is a...    http://www.att.com
#
#                      Twitter  \
# 0   http://twitter.com/Adobe
# 1  http://twitter.com/amazon
# 2     http://twitter.com/aol
# 3                        NaN
# 4     http://twitter.com/ATT
#
#                                   Acquired Companies  \
# 0  Accelio Corporation, Aldus Corp, Amicima, Ares...
# 1  AbeBooks, Accept.Com, Alexa, Amie Street, Audi...
# 2  5min Media, Adap.tv, ADTECH, Advertising.com, ...
# 3  AlgoTrim, Anobit Technologies, AuthenTec, Beat...
# 4  Centennial Communications Corp, Dobson Communi...
#
#                                      Acquisitions ID  \
# 0  Adobe Systems acquired Accelio Corporation in ...
# 1  Amazon acquired AbeBooks in 2008, Amazon acqui...
# 2  AOL acquired 5min Media in 2010, AOL acquired ...
# 3  Apple acquired AlgoTrim in 2013, Apple acquire...
# 4  AT&T acquired Centennial Communications Corp i...
#
#                                                  API
# 0  http://api.crunchbase.com/v/2/organization/ado...
# 1  http://api.crunchbase.com/v/2/organization/ama...
# 2  http://api.crunchbase.com/v/2/organization/aol...
# 3  http://api.crunchbase.com/v/2/organization/app...
# 4  http://api.crunchbase.com/v/2/organization/at-...
#
# [5 rows x 23 columns]
#
#
# ============================================================
# 📁 File: comp.csv
# 📊 Shape: 13826 rows × 14 columns
# 🧾 Columns: ['permalink', 'name', 'homepage_url', 'category_list', 'funding_total_usd', 'status', 'country_code', 'state_code', 'region', 'city', 'funding_rounds', 'founded_at', 'first_funding_at', 'last_funding_at']
# 🔍 Preview:
#                              permalink                    name  \
# 0                  /organization/-fame                   #fame
# 1               /organization/-qounter                :Qounter
# 2  /organization/-the-one-of-them-inc-  (THE) ONE of THEM,Inc.
# 3                /organization/0-6-com                 0-6.com
# 4       /organization/004-technologies        004 Technologies
#
#                         homepage_url  \
# 0                 http://livfame.com
# 1             http://www.qounter.com
# 2                http://oneofthem.jp
# 3                 http://www.0-6.com
# 4  http://004gmbh.de/en/004-interact
#
#                                        category_list funding_total_usd  \
# 0                                              Media          10000000
# 1  Application Platforms|Real Time|Social Network...            700000
# 2                                  Apps|Games|Mobile           3406878
# 3                                        Curated Web           2000000
# 4                                           Software                 -
#
#       status country_code state_code                 region           city  \
# 0  operating          IND         16                 Mumbai         Mumbai
# 1  operating          USA         DE             DE - Other  Delaware City
# 2  operating          NaN        NaN                    NaN            NaN
# 3  operating          CHN         22                Beijing        Beijing
# 4  operating          USA         IL  Springfield, Illinois      Champaign
#
#    funding_rounds  founded_at first_funding_at last_funding_at
# 0             1.0         NaN       2015-01-05      2015-01-05
# 1             2.0  2014-09-04       2014-03-01      2014-10-14
# 2             1.0         NaN       2014-01-30      2014-01-30
# 3             1.0  2007-01-01       2008-03-19      2008-03-19
# 4             1.0  2010-01-01       2014-07-24      2014-07-24
#
#
# ============================================================
# 📁 File: inv.csv
# 📊 Shape: 14323 rows × 18 columns
# 🧾 Columns: ['company_permalink', 'company_name', 'company_category_list', 'company_country_code', 'company_state_code', 'company_region', 'company_city', 'investor_permalink', 'investor_name', 'investor_country_code', 'investor_state_code', 'investor_region', 'investor_city', 'funding_round_permalink', 'funding_round_type', 'funding_round_code', 'funded_at', 'raised_amount_usd']
# 🔍 Preview:
#                   company_permalink        company_name company_category_list  \
# 0             /organization/0-6-com             0-6.com           Curated Web
# 1    /organization/004-technologies    004 Technologies              Software
# 2  /organization/01games-technology  01Games Technology                 Games
# 3              /organization/0xdata              H2O.ai             Analytics
# 4              /organization/0xdata              H2O.ai             Analytics
#
#   company_country_code company_state_code         company_region  \
# 0                  CHN                 22                Beijing
# 1                  USA                 IL  Springfield, Illinois
# 2                  HKG                NaN              Hong Kong
# 3                  USA                 CA            SF Bay Area
# 4                  USA                 CA            SF Bay Area
#
#     company_city                    investor_permalink  \
# 0        Beijing     /organization/dt-capital-partners
# 1      Champaign       /organization/venturecapital-de
# 2      Hong Kong     /organization/cyberport-hong-kong
# 3  Mountain View             /organization/capital-one
# 4  Mountain View  /organization/nexus-venture-partners
#
#             investor_name investor_country_code investor_state_code  \
# 0     DT Capital Partners                   CHN                  23
# 1   VCDE Venture Partners                   DEU                   5
# 2     Cyberport Hong Kong                   HKG                 NaN
# 3             Capital One                   USA                  VA
# 4  Nexus Venture Partners                   USA                  CA
#
#     investor_region investor_city  \
# 0          Shanghai      Shanghai
# 1         Frankfurt     Frankfurt
# 2         Hong Kong     Hong Kong
# 3  Washington, D.C.        Mclean
# 4       SF Bay Area    Menlo Park
#
#                            funding_round_permalink funding_round_type  \
# 0  /funding-round/5727accaeaa57461bd22a9bdd945382d            venture
# 1  /funding-round/1278dd4e6a37fa4b7d7e06c21b3c1830            venture
# 2  /funding-round/7d53696f2b4f607a2f2a8cbb83d01839        undisclosed
# 3  /funding-round/3bb2ee4a2d89251a10aaa735b1180e44            venture
# 4  /funding-round/383a9bd2c04f7038bb543ccef5ba3eae               seed
#
#   funding_round_code   funded_at  raised_amount_usd
# 0                  A  2008-03-19          2000000.0
# 1                NaN  2014-07-24                NaN
# 2                NaN  2014-07-01            41250.0
# 3                  B  2015-11-09         20000000.0
# 4                NaN  2013-05-22          3000000.0
#
#
# ============================================================
# 📁 File: round.csv
# 📊 Shape: 8861 rows × 12 columns
# 🧾 Columns: ['company_permalink', 'company_name', 'company_category_list', 'company_country_code', 'company_state_code', 'company_region', 'company_city', 'funding_round_permalink', 'funding_round_type', 'funding_round_code', 'funded_at', 'raised_amount_usd']
# 🔍 Preview:
#                      company_permalink            company_name  \
# 0                  /organization/-fame                   #fame
# 1               /organization/-qounter                :Qounter
# 2               /organization/-qounter                :Qounter
# 3  /organization/-the-one-of-them-inc-  (THE) ONE of THEM,Inc.
# 4                /organization/0-6-com                 0-6.com
#
#                                company_category_list company_country_code  \
# 0                                              Media                  IND
# 1  Application Platforms|Real Time|Social Network...                  USA
# 2  Application Platforms|Real Time|Social Network...                  USA
# 3                                  Apps|Games|Mobile                  NaN
# 4                                        Curated Web                  CHN
#
#   company_state_code company_region   company_city  \
# 0                 16         Mumbai         Mumbai
# 1                 DE     DE - Other  Delaware City
# 2                 DE     DE - Other  Delaware City
# 3                NaN            NaN            NaN
# 4                 22        Beijing        Beijing
#
#                            funding_round_permalink funding_round_type  \
# 0  /funding-round/9a01d05418af9f794eebff7ace91f638            venture
# 1  /funding-round/22dacff496eb7acb2b901dec1dfe5633            venture
# 2  /funding-round/b44fbb94153f6cdef13083530bb48030               seed
# 3  /funding-round/650b8f704416801069bb178a1418776b            venture
# 4  /funding-round/5727accaeaa57461bd22a9bdd945382d            venture
#
#   funding_round_code   funded_at  raised_amount_usd
# 0                  B  2015-01-05         10000000.0
# 1                  A  2014-10-14                NaN
# 2                NaN  2014-03-01           700000.0
# 3                  B  2014-01-30          3406878.0
# 4                  A  2008-03-19          2000000.0
#
#
# ============================================================
# 📁 File: acq.csv
# 📊 Shape: 18968 rows × 18 columns
# 🧾 Columns: ['company_permalink', 'company_name', 'company_category_list', 'company_country_code', 'company_state_code', 'company_region', 'company_city', 'acquirer_permalink', 'acquirer_name', 'acquirer_category_list', 'acquirer_country_code', 'acquirer_state_code', 'acquirer_region', 'acquirer_city', 'acquired_at', 'acquired_month', 'price_amount', 'price_currency_code']
# 🔍 Preview:
#                                    company_permalink  \
# 0                               /organization/003-ru
# 1                      /organization/0958572-b-c-ltd
# 2                 /organization/1-800-communications
# 3                       /organization/1-800-contacts
# 4  /organization/1-844-446-4460-pogo-customer-ser...
#
#                                         company_name  \
# 0                                             003.RU
# 1                                  0958572 B.C. Ltd.
# 2                               1-800 Communications
# 3                                     1-800 Contacts
# 4  Games Support +1-800-311-5934 Pogo Games techn...
#
#                        company_category_list company_country_code  \
# 0  Consumer Electronics|Electronics|Internet                  RUS
# 1                                        NaN                  NaN
# 2                                        NaN                  USA
# 3                      Consumer Goods|Retail                  USA
# 4                                        NaN                  NaN
#
#   company_state_code  company_region company_city  \
# 0                 48          Moscow       Moscow
# 1                NaN             NaN          NaN
# 2                 NY     Long Island   Hicksville
# 3                 UT  Salt Lake City       Draper
# 4                NaN             NaN          NaN
#
#                                   acquirer_permalink  \
# 0                         /organization/media-saturn
# 1  /organization/atlas-intellectual-property-mana...
# 2                       /organization/carsdirect-com
# 3                /organization/thomas-h-lee-partners
# 4  /organization/pogo-customer-service-number-1-8...
#
#                                        acquirer_name  \
# 0                                       Media Saturn
# 1         ATLAS Intellectual Property Management Co.
# 2                                     CarsDirect.com
# 3                             Thomas H. Lee Partners
# 4  Games Support +1-800-311-5934 Pogo Games techn...
#
#                               acquirer_category_list acquirer_country_code  \
# 0      Enterprise Software|Media|Sales and Marketing                   ESP
# 1          Finance|FinTech|Mobile|Telecommunications                   USA
# 2                                         E-Commerce                   USA
# 3  Business Development|Impact Investing|Investme...                   USA
# 4                                                NaN                   USA
#
#   acquirer_state_code acquirer_region acquirer_city acquired_at  \
# 0                  56       Barcelona     Barcelona  2012-07-23
# 1                  WA         Seattle       Seattle  2012-02-02
# 2                  CA     Los Angeles    El Segundo  2005-06-12
# 3                  MA          Boston        Boston  2014-01-07
# 4                  NY   New York City    Mamaroneck  2001-02-02
#
#   acquired_month  price_amount price_currency_code
# 0        2012-07           NaN                 USD
# 1        2012-02     9000000.0                 USD
# 2        2005-06           NaN                 USD
# 3        2014-01           NaN                 USD
# 4        2001-02           NaN                 USD
#
#
# ============================================================
# 📁 File: Acquired Tech Companies.csv
# 📊 Shape: 1610 rows × 16 columns
# 🧾 Columns: ['Company', 'CrunchBase Profile', 'Image', 'Tagline', 'Year Founded', 'Market Categories', 'Address (HQ)', 'City (HQ)', 'State / Region (HQ)', 'Country (HQ)', 'Description', 'Homepage', 'Twitter', 'Acquired by', 'Acquisitions ID', 'API']
# 🔍 Preview:
#                Company                                 CrunchBase Profile  \
# 0  Accelio Corporation  http://www.crunchbase.com/organization/accelio...
# 1           Aldus Corp  http://www.crunchbase.com/organization/aldus-corp
# 2              Amicima     http://www.crunchbase.com/organization/amicima
# 3        Ares Software  http://www.crunchbase.com/organization/ares-so...
# 4             Auditude    http://www.crunchbase.com/organization/auditude
#
#                                                Image  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4  http://a3.images.crunchbase.com/image/upload/c...
#
#                                              Tagline  Year Founded  \
# 0  Accelio Corporation develops web-based softwar...           NaN
# 1  Aldus Corporation, named after the 15th-centur...        1984.0
# 2                                  Network Protocols           NaN
# 3      Ares Software was added to CrunchBase in 2010           NaN
# 4  Auditude, a video management and monetization ...        1999.0
#
#                   Market Categories  \
# 0                               NaN
# 1                          Software
# 2                          Software
# 3                               NaN
# 4  Monetization, Advertising, Video
#
#                                         Address (HQ)   City (HQ)  \
# 0      560 Rochester Street, Ottawa, Ontario, Canada      Ottawa
# 1                 Seattle, Washington, United States     Seattle
# 2              Santa Cruz, California, United States  Santa Cruz
# 3                                                NaN         NaN
# 4  849 High Street, Palo Alto, California, United...   Palo Alto
#
#   State / Region (HQ)   Country (HQ)  \
# 0             Ontario         Canada
# 1          Washington  United States
# 2          California  United States
# 3                 NaN            NaN
# 4          California  United States
#
#                                          Description                 Homepage  \
# 0  Accelio Corporation Formerly known as Jetform ...                      NaN
# 1  Aldus Corporation, named after the 15th-centur...                      NaN
# 2  Amicima, Inc. was a software company headquart...                      NaN
# 3                                                NaN                      NaN
# 4  Auditude is a leading video management and mon...  http://www.auditude.com
#
#                        Twitter Acquired by  \
# 0                          NaN       Adobe
# 1                          NaN       Adobe
# 2                          NaN       Adobe
# 3                          NaN       Adobe
# 4  http://twitter.com/auditude       Adobe
#
#                                      Acquisitions ID  \
# 0  Adobe Systems acquired Accelio Corporation in ...
# 1          Adobe Systems acquired Aldus Corp in 1994
# 2             Adobe Systems acquired Amicima in 2006
# 3       Adobe Systems acquired Ares Software in 1996
# 4            Adobe Systems acquired Auditude in 2011
#
#                                                  API
# 0  http://api.crunchbase.com/v/2/organization/acc...
# 1  http://api.crunchbase.com/v/2/organization/ald...
# 2  http://api.crunchbase.com/v/2/organization/ami...
# 3  http://api.crunchbase.com/v/2/organization/are...
# 4  http://api.crunchbase.com/v/2/organization/aud...
#
#
# ============================================================
# 📁 File: Acquisitions.csv
# 📊 Shape: 1643 rows × 11 columns
# 🧾 Columns: ['Acquisitions ID', 'Acquired Company', 'Acquiring Company', 'Year of acquisition announcement', 'Deal announced on', 'Price', 'Status', 'Terms', 'Acquisition Profile', 'News', 'News Link']
# 🔍 Preview:
#                                      Acquisitions ID     Acquired Company  \
# 0                      [24]7 acquired Tellme in 2012               Tellme
# 1                         3Com acquired Palm in 1997                 Palm
# 2  Adobe Systems acquired Accelio Corporation in ...  Accelio Corporation
# 3          Adobe Systems acquired Aldus Corp in 1994           Aldus Corp
# 4             Adobe Systems acquired Amicima in 2006              Amicima
#
#   Acquiring Company  Year of acquisition announcement Deal announced on  \
# 0             [24]7                              2012         1/02/2012
# 1              3Com                              1997         1/06/1997
# 2             Adobe                              2002        15/04/2002
# 3             Adobe                              1994        31/08/1994
# 4             Adobe                              2006        28/06/1905
#
#                 Price       Status        Terms  \
# 0  Undisclosed amount  Undisclosed  Undisclosed
# 1  Undisclosed amount  Undisclosed  Undisclosed
# 2  Undisclosed amount  Undisclosed  Undisclosed
# 3  Undisclosed amount  Undisclosed  Undisclosed
# 4  Undisclosed amount  Undisclosed  Undisclosed
#
#                                  Acquisition Profile  \
# 0  http://www.crunchbase.com/acquisition/a9e7a5ac...
# 1  http://www.crunchbase.com/acquisition/65869a9a...
# 2  http://www.crunchbase.com/acquisition/ba5294ea...
# 3  http://www.crunchbase.com/acquisition/e9ddca86...
# 4  http://www.crunchbase.com/acquisition/97db67f9...
#
#                                                 News  \
# 0  Microsoft and 24/7 Inc. Join Forces to Deliver...
# 1        Investors bless 3Com-USR merger - CNET News
# 2         Adobe Systems acquired Accelio Corporation
# 3                  Adobe Systems acquired Aldus Corp
# 4                                                NaN
#
#                                            News Link
# 0  http://www.microsoft.com/en-us/news/press/2012...
# 1  http://news.cnet.com/Investors-bless-3Com-USR-...
# 2  http://www.alacrastore.com/storecontent/Thomso...
# 3  http://www.alacrastore.com/storecontent/Thomso...
# 4                                                NaN

# %%
import os
import pandas as pd
from sqlalchemy import create_engine

# MySQL connection details
username = 'root'
password = '4064255Aa()'
host = 'localhost'  
port = '3306'
database = 'Merge_Acquisitions'

# Create the SQLAlchemy engine
engine = create_engine(f'mysql+pymysql://{username}:{password}@{host}:{port}/{database}')
csv_folder = '.'  # Update if needed

# Loop through CSV files
for filename in os.listdir(csv_folder):
    if filename.endswith('.csv'):
        filepath = os.path.join(csv_folder, filename)
        table_name = os.path.splitext(filename)[0].replace(' ', '_').lower()
        print(f"🚀 Loading {filename} into MySQL table `{table_name}`")

        try:
            df = pd.read_csv(filepath)
            df.to_sql(table_name, con=engine, if_exists='replace', index=False)
        except Exception as e:
            print(f"❌ Failed to load {filename}: {e}")
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[1], line 3
#       1 import os
#       2 import pandas as pd
# ----> 3 from sqlalchemy import create_engine
#       5 # MySQL connection details
#       6 username = 'root'
#
# File ~/miniforge3/envs/dsc80/lib/python3.12/site-packages/sqlalchemy/__init__.py:12
#       8 from __future__ import annotations
#      10 from typing import Any
# ---> 12 from . import util as _util
#      13 from .engine import AdaptedConnection as AdaptedConnection
#      14 from .engine import BaseRow as BaseRow
#
# File ~/miniforge3/envs/dsc80/lib/python3.12/site-packages/sqlalchemy/util/__init__.py:14
#      11 from functools import update_wrapper as update_wrapper
#      13 from . import preloaded as preloaded
# ---> 14 from ._collections import coerce_generator_arg as coerce_generator_arg
#      15 from ._collections import coerce_to_immutabledict as coerce_to_immutabledict
#      16 from ._collections import column_dict as column_dict
#
# File ~/miniforge3/envs/dsc80/lib/python3.12/site-packages/sqlalchemy/util/_collections.py:39
#      36 import weakref
#      38 from ._has_cy import HAS_CYEXTENSION
# ---> 39 from .typing import is_non_string_iterable
#      40 from .typing import Literal
#      41 from .typing import Protocol
#
# File ~/miniforge3/envs/dsc80/lib/python3.12/site-packages/sqlalchemy/util/typing.py:58
#      56 from typing_extensions import TypeGuard as TypeGuard  # 3.10
#      57 from typing_extensions import Self as Self  # 3.11
# ---> 58 from typing_extensions import TypeAliasType as TypeAliasType  # 3.12
#      59 from typing_extensions import Never as Never  # 3.11
#      60 from typing_extensions import LiteralString as LiteralString  # 3.11
#
# ImportError: cannot import name 'TypeAliasType' from 'typing_extensions' (/Users/yuxing/miniforge3/envs/dsc80/lib/python3.12/site-packages/typing_extensions/__init__.py)

# %%
import pandas as pd

# read with latin-1 (which can decode all bytes 0–255)
df = pd.read_csv("Acquired Tech Companies.csv", encoding="latin1")

# write it back out as strict UTF-8
df.to_csv("Acquired Tech Companies_utf8.csv", index=False, encoding="utf-8")

# %%
import io, sys

with open("Acquired_Tech_Companies_utf8.csv", "rb") as fin, \
     open("Acquired_ASCII_only.csv", "wb") as fout:
    data = fin.read()
    # keep only bytes in the ASCII range 0–127
    ascii_data = data.translate(None, bytes(range(128,256)))
    fout.write(ascii_data)

# %%
import io, sys

with open("comp.csv", "rb") as fin, \
     open("comp_ASCII_only.csv", "wb") as fout:
    data = fin.read()
    # drop every byte ≥ 128
    ascii_data = data.translate(None, bytes(range(128,256)))
    fout.write(ascii_data)

# %%
import os
import pandas as pd

# point this at wherever your CSVs live
csv_dir = r"/Users/yuxing/Desktop/Data Analyst Project/DS3_Project"

for fname in os.listdir(csv_dir):
    if fname.lower().endswith(".csv"):
        full_path = os.path.join(csv_dir, fname)
        print(f"\n=== Contents of {fname} ===")
        try:
            df = pd.read_csv(full_path)
            # show the first 5 rows (or use df.head(n) for more/less)
            print(df.head())
        except Exception as e:
            print(f"  ⚠️  could not read {fname}: {e}")
# Out:
# === Contents of addition.csv ===
#         content month_str  year_str  value
# 0  Acquisitions   1960-01      1960      1
# 1  Acquisitions   1966-11      1966      1
# 2  Acquisitions   1967-04      1967      1
# 3  Acquisitions   1972-01      1972      1
# 4  Acquisitions   1973-01      1973      1
#
# === Contents of Acquired_Tech_Companies_utf8.csv ===
#                Company                                 CrunchBase Profile  \
# 0  Accelio Corporation  http://www.crunchbase.com/organization/accelio...
# 1           Aldus Corp  http://www.crunchbase.com/organization/aldus-corp
# 2              Amicima     http://www.crunchbase.com/organization/amicima
# 3        Ares Software  http://www.crunchbase.com/organization/ares-so...
# 4             Auditude    http://www.crunchbase.com/organization/auditude
#
#                                                Image  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4  http://a3.images.crunchbase.com/image/upload/c...
#
#                                              Tagline  Year Founded  \
# 0  Accelio Corporation develops web-based softwar...           NaN
# 1  Aldus Corporation, named after the 15th-centur...        1984.0
# 2                                  Network Protocols           NaN
# 3      Ares Software was added to CrunchBase in 2010           NaN
# 4  Auditude, a video management and monetization ...        1999.0
#
#                   Market Categories  \
# 0                               NaN
# 1                          Software
# 2                          Software
# 3                               NaN
# 4  Monetization, Advertising, Video
#
#                                         Address (HQ)   City (HQ)  \
# 0      560 Rochester Street, Ottawa, Ontario, Canada      Ottawa
# 1                 Seattle, Washington, United States     Seattle
# 2              Santa Cruz, California, United States  Santa Cruz
# 3                                                NaN         NaN
# 4  849 High Street, Palo Alto, California, United...   Palo Alto
#
#   State / Region (HQ)   Country (HQ)  \
# 0             Ontario         Canada
# 1          Washington  United States
# 2          California  United States
# 3                 NaN            NaN
# 4          California  United States
#
#                                          Description                 Homepage  \
# 0  Accelio Corporation Formerly known as Jetform ...                      NaN
# 1  Aldus Corporation, named after the 15th-centur...                      NaN
# 2  Amicima, Inc. was a software company headquart...                      NaN
# 3                                                NaN                      NaN
# 4  Auditude is a leading video management and mon...  http://www.auditude.com
#
#                        Twitter Acquired by  \
# 0                          NaN       Adobe
# 1                          NaN       Adobe
# 2                          NaN       Adobe
# 3                          NaN       Adobe
# 4  http://twitter.com/auditude       Adobe
#
#                                      Acquisitions ID  \
# 0  Adobe Systems acquired Accelio Corporation in ...
# 1          Adobe Systems acquired Aldus Corp in 1994
# 2             Adobe Systems acquired Amicima in 2006
# 3       Adobe Systems acquired Ares Software in 1996
# 4            Adobe Systems acquired Auditude in 2011
#
#                                                  API
# 0  http://api.crunchbase.com/v/2/organization/acc...
# 1  http://api.crunchbase.com/v/2/organization/ald...
# 2  http://api.crunchbase.com/v/2/organization/ami...
# 3  http://api.crunchbase.com/v/2/organization/are...
# 4  http://api.crunchbase.com/v/2/organization/aud...
#
# === Contents of Founders and Board Members.csv ===
#                     Name                                 CrunchBase Profile  \
# 0     Hans-Werner Hector    http://de.wikipedia.org/wiki/Hans-Werner_Hector
# 1            Akio Morita           http://en.wikipedia.org/wiki/Akio_Morita
# 2  Alexander Graham Bell  http://en.wikipedia.org/wiki/Alexander_Graham_...
# 3         Andrew Viterbi        http://en.wikipedia.org/wiki/Andrew_Viterbi
# 4              Bob Miner             http://en.wikipedia.org/wiki/Bob_Miner
#
#       Role Companies                                              Image
# 0  Founder       SAP  http://images.forbes.com/media/lists/10/2006/4...
# 1  Founder      Sony       http://www.adeptis.ru/vinci/akio_morita3.jpg
# 2  Founder      AT&T  https://upload.wikimedia.org/wikipedia/commons...
# 3  Founder  Qualcomm  https://alum.mit.edu/sites/default/files/migra...
# 4  Founder    Oracle  https://upload.wikimedia.org/wikipedia/commons...
#
# === Contents of Acquiring Tech Companies.csv ===
#   Acquiring Company                             CrunchBase Profile  \
# 0             Adobe  www.crunchbase.com/organization/adobe-systems
# 1            Amazon         www.crunchbase.com/organization/amazon
# 2               AOL            www.crunchbase.com/organization/aol
# 3             Apple          www.crunchbase.com/organization/apple
# 4              AT&T           www.crunchbase.com/organization/at-t
#
#                                                Image  \
# 0  http://a2.images.crunchbase.com/image/upload/c...
# 1  http://a4.images.crunchbase.com/image/upload/c...
# 2  http://a5.images.crunchbase.com/image/upload/c...
# 3  http://a4.images.crunchbase.com/image/upload/c...
# 4  http://a4.images.crunchbase.com/image/upload/c...
#
#                                              Tagline  \
# 0  Adobe is an American multinational computer so...
# 1  Amazon is an international e-commerce company ...
# 2  AOL is a Brand company committed to innovating...
# 3  Apple is a multinational corporation that desi...
# 4  AT&T provides telecommunications services such...
#
#                                    Market Categories  Year Founded   IPO  \
# 0  Photo Editing, Design, Creative, Software, Ima...          1982  1986
# 1  Groceries, Consumer Goods, Crowdsourcing, E-Co...          1994  1997
# 2  News, Advertising Platforms, Content Creators,...          1985  2009
# 3  Computers, Consumer Electronics, Hardware + So...          1976  1980
# 4                                             Mobile          2000  1983
#
#                                   Founders Number of Employees  \
# 0            John Warnock, Charles Geschke              11,144
# 1                               Jeff Bezos             132,600
# 2      Marc Seriff, Steve Case, Jim Kimsey               5,600
# 3  Steve Jobs, Ronald Wayne, Steve Wozniak              98,000
# 4                    Alexander Graham Bell             246,740
#
#    Number of Employees (year of last update)  ...  \
# 0                                     2012.0  ...
# 1                                     2014.0  ...
# 2                                     2012.0  ...
# 3                                     2014.0  ...
# 4                                     2013.0  ...
#
#                                         Address (HQ)      City (HQ)  \
# 0                San Jose, California, United States       San Jose
# 1              1200 12th Ave, Seattle, WA 98144, USA        Seattle
# 2  770 Broadway, New York City, New York, United ...  New York City
# 3  1 Infinite Loop, Cupertino, California, United...      Cupertino
# 4      208 S. Akard St, Dallas, Texas, United States         Dallas
#
#   State / Region (HQ)   Country (HQ)  \
# 0          California  United States
# 1          Washington  United States
# 2            New York  United States
# 3          California  United States
# 4               Texas  United States
#
#                                          Description              Homepage  \
# 0  Adobe Systems is an American multinational com...  http://www.adobe.com
# 1  Amazon.com is an American international e-comm...     http://amazon.com
# 2  AOL is a global advertising-supported Web comp...    http://www.aol.com
# 3  Apple is an American multinational corporation...  http://www.apple.com
# 4  AT&T Inc. AT&T is a holding company. AT&T is a...    http://www.att.com
#
#                      Twitter  \
# 0   http://twitter.com/Adobe
# 1  http://twitter.com/amazon
# 2     http://twitter.com/aol
# 3                        NaN
# 4     http://twitter.com/ATT
#
#                                   Acquired Companies  \
# 0  Accelio Corporation, Aldus Corp, Amicima, Ares...
# 1  AbeBooks, Accept.Com, Alexa, Amie Street, Audi...
# 2  5min Media, Adap.tv, ADTECH, Advertising.com, ...
# 3  AlgoTrim, Anobit Technologies, AuthenTec, Beat...
# 4  Centennial Communications Corp, Dobson Communi...
#
#                                      Acquisitions ID  \
# 0  Adobe Systems acquired Accelio Corporation in ...
# 1  Amazon acquired AbeBooks in 2008, Amazon acqui...
# 2  AOL acquired 5min Media in 2010, AOL acquired ...
# 3  Apple acquired AlgoTrim in 2013, Apple acquire...
# 4  AT&T acquired Centennial Communications Corp i...
#
#                                                  API
# 0  http://api.crunchbase.com/v/2/organization/ado...
# 1  http://api.crunchbase.com/v/2/organization/ama...
# 2  http://api.crunchbase.com/v/2/organization/aol...
# 3  http://api.crunchbase.com/v/2/organization/app...
# 4  http://api.crunchbase.com/v/2/organization/at-...
#
# [5 rows x 23 columns]
#
# === Contents of comp.csv ===
#                              permalink                    name  \
# 0                  /organization/-fame                   #fame
# 1               /organization/-qounter                :Qounter
# 2  /organization/-the-one-of-them-inc-  (THE) ONE of THEM,Inc.
# 3                /organization/0-6-com                 0-6.com
# 4       /organization/004-technologies        004 Technologies
#
#                         homepage_url  \
# 0                 http://livfame.com
# 1             http://www.qounter.com
# 2                http://oneofthem.jp
# 3                 http://www.0-6.com
# 4  http://004gmbh.de/en/004-interact
#
#                                        category_list funding_total_usd  \
# 0                                              Media          10000000
# 1  Application Platforms|Real Time|Social Network...            700000
# 2                                  Apps|Games|Mobile           3406878
# 3                                        Curated Web           2000000
# 4                                           Software                 -
#
#       status country_code state_code                 region           city  \
# 0  operating          IND         16                 Mumbai         Mumbai
# 1  operating          USA         DE             DE - Other  Delaware City
# 2  operating          NaN        NaN                    NaN            NaN
# 3  operating          CHN         22                Beijing        Beijing
# 4  operating          USA         IL  Springfield, Illinois      Champaign
#
#    funding_rounds  founded_at first_funding_at last_funding_at
# 0             1.0         NaN       2015-01-05      2015-01-05
# 1             2.0  2014-09-04       2014-03-01      2014-10-14
# 2             1.0         NaN       2014-01-30      2014-01-30
# 3             1.0  2007-01-01       2008-03-19      2008-03-19
# 4             1.0  2010-01-01       2014-07-24      2014-07-24
#
# === Contents of inv.csv ===
#                   company_permalink        company_name company_category_list  \
# 0             /organization/0-6-com             0-6.com           Curated Web
# 1    /organization/004-technologies    004 Technologies              Software
# 2  /organization/01games-technology  01Games Technology                 Games
# 3              /organization/0xdata              H2O.ai             Analytics
# 4              /organization/0xdata              H2O.ai             Analytics
#
#   company_country_code company_state_code         company_region  \
# 0                  CHN                 22                Beijing
# 1                  USA                 IL  Springfield, Illinois
# 2                  HKG                NaN              Hong Kong
# 3                  USA                 CA            SF Bay Area
# 4                  USA                 CA            SF Bay Area
#
#     company_city                    investor_permalink  \
# 0        Beijing     /organization/dt-capital-partners
# 1      Champaign       /organization/venturecapital-de
# 2      Hong Kong     /organization/cyberport-hong-kong
# 3  Mountain View             /organization/capital-one
# 4  Mountain View  /organization/nexus-venture-partners
#
#             investor_name investor_country_code investor_state_code  \
# 0     DT Capital Partners                   CHN                  23
# 1   VCDE Venture Partners                   DEU                   5
# 2     Cyberport Hong Kong                   HKG                 NaN
# 3             Capital One                   USA                  VA
# 4  Nexus Venture Partners                   USA                  CA
#
#     investor_region investor_city  \
# 0          Shanghai      Shanghai
# 1         Frankfurt     Frankfurt
# 2         Hong Kong     Hong Kong
# 3  Washington, D.C.        Mclean
# 4       SF Bay Area    Menlo Park
#
#                            funding_round_permalink funding_round_type  \
# 0  /funding-round/5727accaeaa57461bd22a9bdd945382d            venture
# 1  /funding-round/1278dd4e6a37fa4b7d7e06c21b3c1830            venture
# 2  /funding-round/7d53696f2b4f607a2f2a8cbb83d01839        undisclosed
# 3  /funding-round/3bb2ee4a2d89251a10aaa735b1180e44            venture
# 4  /funding-round/383a9bd2c04f7038bb543ccef5ba3eae               seed
#
#   funding_round_code   funded_at  raised_amount_usd
# 0                  A  2008-03-19          2000000.0
# 1                NaN  2014-07-24                NaN
# 2                NaN  2014-07-01            41250.0
# 3                  B  2015-11-09         20000000.0
# 4                NaN  2013-05-22          3000000.0
#
# === Contents of Acquired_ASCII_only.csv ===
#                Company                                 CrunchBase Profile  \
# 0  Accelio Corporation  http://www.crunchbase.com/organization/accelio...
# 1           Aldus Corp  http://www.crunchbase.com/organization/aldus-corp
# 2              Amicima     http://www.crunchbase.com/organization/amicima
# 3        Ares Software  http://www.crunchbase.com/organization/ares-so...
# 4             Auditude    http://www.crunchbase.com/organization/auditude
#
#                                                Image  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4  http://a3.images.crunchbase.com/image/upload/c...
#
#                                              Tagline  Year Founded  \
# 0  Accelio Corporation develops web-based softwar...           NaN
# 1  Aldus Corporation, named after the 15th-centur...        1984.0
# 2                                  Network Protocols           NaN
# 3      Ares Software was added to CrunchBase in 2010           NaN
# 4  Auditude, a video management and monetization ...        1999.0
#
#                   Market Categories  \
# 0                               NaN
# 1                          Software
# 2                          Software
# 3                               NaN
# 4  Monetization, Advertising, Video
#
#                                         Address (HQ)   City (HQ)  \
# 0      560 Rochester Street, Ottawa, Ontario, Canada      Ottawa
# 1                 Seattle, Washington, United States     Seattle
# 2              Santa Cruz, California, United States  Santa Cruz
# 3                                                NaN         NaN
# 4  849 High Street, Palo Alto, California, United...   Palo Alto
#
#   State / Region (HQ)   Country (HQ)  \
# 0             Ontario         Canada
# 1          Washington  United States
# 2          California  United States
# 3                 NaN            NaN
# 4          California  United States
#
#                                          Description                 Homepage  \
# 0  Accelio Corporation Formerly known as Jetform ...                      NaN
# 1  Aldus Corporation, named after the 15th-centur...                      NaN
# 2  Amicima, Inc. was a software company headquart...                      NaN
# 3                                                NaN                      NaN
# 4  Auditude is a leading video management and mon...  http://www.auditude.com
#
#                        Twitter Acquired by  \
# 0                          NaN       Adobe
# 1                          NaN       Adobe
# 2                          NaN       Adobe
# 3                          NaN       Adobe
# 4  http://twitter.com/auditude       Adobe
#
#                                      Acquisitions ID  \
# 0  Adobe Systems acquired Accelio Corporation in ...
# 1          Adobe Systems acquired Aldus Corp in 1994
# 2             Adobe Systems acquired Amicima in 2006
# 3       Adobe Systems acquired Ares Software in 1996
# 4            Adobe Systems acquired Auditude in 2011
#
#                                                  API
# 0  http://api.crunchbase.com/v/2/organization/acc...
# 1  http://api.crunchbase.com/v/2/organization/ald...
# 2  http://api.crunchbase.com/v/2/organization/ami...
# 3  http://api.crunchbase.com/v/2/organization/are...
# 4  http://api.crunchbase.com/v/2/organization/aud...
#
# === Contents of round.csv ===
#                      company_permalink            company_name  \
# 0                  /organization/-fame                   #fame
# 1               /organization/-qounter                :Qounter
# 2               /organization/-qounter                :Qounter
# 3  /organization/-the-one-of-them-inc-  (THE) ONE of THEM,Inc.
# 4                /organization/0-6-com                 0-6.com
#
#                                company_category_list company_country_code  \
# 0                                              Media                  IND
# 1  Application Platforms|Real Time|Social Network...                  USA
# 2  Application Platforms|Real Time|Social Network...                  USA
# 3                                  Apps|Games|Mobile                  NaN
# 4                                        Curated Web                  CHN
#
#   company_state_code company_region   company_city  \
# 0                 16         Mumbai         Mumbai
# 1                 DE     DE - Other  Delaware City
# 2                 DE     DE - Other  Delaware City
# 3                NaN            NaN            NaN
# 4                 22        Beijing        Beijing
#
#                            funding_round_permalink funding_round_type  \
# 0  /funding-round/9a01d05418af9f794eebff7ace91f638            venture
# 1  /funding-round/22dacff496eb7acb2b901dec1dfe5633            venture
# 2  /funding-round/b44fbb94153f6cdef13083530bb48030               seed
# 3  /funding-round/650b8f704416801069bb178a1418776b            venture
# 4  /funding-round/5727accaeaa57461bd22a9bdd945382d            venture
#
#   funding_round_code   funded_at  raised_amount_usd
# 0                  B  2015-01-05         10000000.0
# 1                  A  2014-10-14                NaN
# 2                NaN  2014-03-01           700000.0
# 3                  B  2014-01-30          3406878.0
# 4                  A  2008-03-19          2000000.0
#
# === Contents of acq.csv ===
#                                    company_permalink  \
# 0                               /organization/003-ru
# 1                      /organization/0958572-b-c-ltd
# 2                 /organization/1-800-communications
# 3                       /organization/1-800-contacts
# 4  /organization/1-844-446-4460-pogo-customer-ser...
#
#                                         company_name  \
# 0                                             003.RU
# 1                                  0958572 B.C. Ltd.
# 2                               1-800 Communications
# 3                                     1-800 Contacts
# 4  Games Support +1-800-311-5934 Pogo Games techn...
#
#                        company_category_list company_country_code  \
# 0  Consumer Electronics|Electronics|Internet                  RUS
# 1                                        NaN                  NaN
# 2                                        NaN                  USA
# 3                      Consumer Goods|Retail                  USA
# 4                                        NaN                  NaN
#
#   company_state_code  company_region company_city  \
# 0                 48          Moscow       Moscow
# 1                NaN             NaN          NaN
# 2                 NY     Long Island   Hicksville
# 3                 UT  Salt Lake City       Draper
# 4                NaN             NaN          NaN
#
#                                   acquirer_permalink  \
# 0                         /organization/media-saturn
# 1  /organization/atlas-intellectual-property-mana...
# 2                       /organization/carsdirect-com
# 3                /organization/thomas-h-lee-partners
# 4  /organization/pogo-customer-service-number-1-8...
#
#                                        acquirer_name  \
# 0                                       Media Saturn
# 1         ATLAS Intellectual Property Management Co.
# 2                                     CarsDirect.com
# 3                             Thomas H. Lee Partners
# 4  Games Support +1-800-311-5934 Pogo Games techn...
#
#                               acquirer_category_list acquirer_country_code  \
# 0      Enterprise Software|Media|Sales and Marketing                   ESP
# 1          Finance|FinTech|Mobile|Telecommunications                   USA
# 2                                         E-Commerce                   USA
# 3  Business Development|Impact Investing|Investme...                   USA
# 4                                                NaN                   USA
#
#   acquirer_state_code acquirer_region acquirer_city acquired_at  \
# 0                  56       Barcelona     Barcelona  2012-07-23
# 1                  WA         Seattle       Seattle  2012-02-02
# 2                  CA     Los Angeles    El Segundo  2005-06-12
# 3                  MA          Boston        Boston  2014-01-07
# 4                  NY   New York City    Mamaroneck  2001-02-02
#
#   acquired_month  price_amount price_currency_code
# 0        2012-07           NaN                 USD
# 1        2012-02     9000000.0                 USD
# 2        2005-06           NaN                 USD
# 3        2014-01           NaN                 USD
# 4        2001-02           NaN                 USD
#
# === Contents of comp_ASCII_only.csv ===
#                              permalink                    name  \
# 0                  /organization/-fame                   #fame
# 1               /organization/-qounter                :Qounter
# 2  /organization/-the-one-of-them-inc-  (THE) ONE of THEM,Inc.
# 3                /organization/0-6-com                 0-6.com
# 4       /organization/004-technologies        004 Technologies
#
#                         homepage_url  \
# 0                 http://livfame.com
# 1             http://www.qounter.com
# 2                http://oneofthem.jp
# 3                 http://www.0-6.com
# 4  http://004gmbh.de/en/004-interact
#
#                                        category_list funding_total_usd  \
# 0                                              Media          10000000
# 1  Application Platforms|Real Time|Social Network...            700000
# 2                                  Apps|Games|Mobile           3406878
# 3                                        Curated Web           2000000
# 4                                           Software                 -
#
#       status country_code state_code                 region           city  \
# 0  operating          IND         16                 Mumbai         Mumbai
# 1  operating          USA         DE             DE - Other  Delaware City
# 2  operating          NaN        NaN                    NaN            NaN
# 3  operating          CHN         22                Beijing        Beijing
# 4  operating          USA         IL  Springfield, Illinois      Champaign
#
#    funding_rounds  founded_at first_funding_at last_funding_at
# 0             1.0         NaN       2015-01-05      2015-01-05
# 1             2.0  2014-09-04       2014-03-01      2014-10-14
# 2             1.0         NaN       2014-01-30      2014-01-30
# 3             1.0  2007-01-01       2008-03-19      2008-03-19
# 4             1.0  2010-01-01       2014-07-24      2014-07-24
#
# === Contents of Acquisitions.csv ===
#                                      Acquisitions ID     Acquired Company  \
# 0                      [24]7 acquired Tellme in 2012               Tellme
# 1                         3Com acquired Palm in 1997                 Palm
# 2  Adobe Systems acquired Accelio Corporation in ...  Accelio Corporation
# 3          Adobe Systems acquired Aldus Corp in 1994           Aldus Corp
# 4             Adobe Systems acquired Amicima in 2006              Amicima
#
#   Acquiring Company  Year of acquisition announcement Deal announced on  \
# 0             [24]7                              2012         1/02/2012
# 1              3Com                              1997         1/06/1997
# 2             Adobe                              2002        15/04/2002
# 3             Adobe                              1994        31/08/1994
# 4             Adobe                              2006        28/06/1905
#
#                 Price       Status        Terms  \
# 0  Undisclosed amount  Undisclosed  Undisclosed
# 1  Undisclosed amount  Undisclosed  Undisclosed
# 2  Undisclosed amount  Undisclosed  Undisclosed
# 3  Undisclosed amount  Undisclosed  Undisclosed
# 4  Undisclosed amount  Undisclosed  Undisclosed
#
#                                  Acquisition Profile  \
# 0  http://www.crunchbase.com/acquisition/a9e7a5ac...
# 1  http://www.crunchbase.com/acquisition/65869a9a...
# 2  http://www.crunchbase.com/acquisition/ba5294ea...
# 3  http://www.crunchbase.com/acquisition/e9ddca86...
# 4  http://www.crunchbase.com/acquisition/97db67f9...
#
#                                                 News  \
# 0  Microsoft and 24/7 Inc. Join Forces to Deliver...
# 1        Investors bless 3Com-USR merger - CNET News
# 2         Adobe Systems acquired Accelio Corporation
# 3                  Adobe Systems acquired Aldus Corp
# 4                                                NaN
#
#                                            News Link
# 0  http://www.microsoft.com/en-us/news/press/2012...
# 1  http://news.cnet.com/Investors-bless-3Com-USR-...
# 2  http://www.alacrastore.com/storecontent/Thomso...
# 3  http://www.alacrastore.com/storecontent/Thomso...
# 4                                                NaN

# %%
comp             = pd.read_csv("comp.csv")                              # base company info
inv              = pd.read_csv("inv.csv")                               # investors
rounds           = pd.read_csv("round.csv")                             # funding rounds
acq              = pd.read_csv("acq.csv")                               # acquisitions history
acq_tech         = pd.read_csv("Acquired_ASCII_only.csv")               # acquired tech co’s
acquiring_tech   = pd.read_csv("Acquiring Tech Companies.csv")          # acquirers
acquisitions     = pd.read_csv("Acquisitions.csv")                     # deal details
addition         = pd.read_csv("addition.csv")                          # macro time series
founders_board   = pd.read_csv("Founders and Board Members.csv")

# %%
all=pd.merge(
    acq,
    acq_tech,
    left_on="company_name",
    right_on="Company",
    how="outer"
)

# %%
all.head()
all = all.drop(columns=['company_permalink', 'acquirer_permalink', 'Homepage','Twitter'])
# Out:
#      company_name                     company_category_list  \
# 0        #waywire  Entertainment|News|Politics|Social Media
# 1           (RED)                                Nonprofits
# 2  (fluff)Friends                                       NaN
# 3             .CO            Curated Web|Domains|Registrars
# 4      .vantronix  Cloud Security|Network Security|Security
#
#   company_country_code company_state_code company_region company_city  \
# 0                  USA                 NY  New York City     New York
# 1                  USA                 NY  New York City     New York
# 2                  NaN                NaN            NaN          NaN
# 3                  USA                 FL          Miami        Miami
# 4                  DEU                  6        Hanover      Hanover
#
#                   acquirer_name  \
# 0              Waywire Networks
# 1  Nationstar Mortgage Holdings
# 2   SGN (Social Gaming Network)
# 3                       Neustar
# 4                   Compumatica
#
#                               acquirer_category_list acquirer_country_code  \
# 0                                  Curated Web|Video                   USA
# 1                                            Finance                   USA
# 2                                              Games                   USA
# 3  Advertising|Analytics|Digital Media|Domains|In...                   USA
# 4                                                NaN                   NaN
#
#   acquirer_state_code  ... Year Founded Market Categories Address (HQ)  \
# 0                  NY  ...          NaN               NaN          NaN
# 1                  TX  ...          NaN               NaN          NaN
# 2                  CA  ...          NaN               NaN          NaN
# 3                  VA  ...          NaN               NaN          NaN
# 4                 NaN  ...          NaN               NaN          NaN
#
#   City (HQ)  State / Region (HQ) Country (HQ) Description Acquired by  \
# 0       NaN                  NaN          NaN         NaN         NaN
# 1       NaN                  NaN          NaN         NaN         NaN
# 2       NaN                  NaN          NaN         NaN         NaN
# 3       NaN                  NaN          NaN         NaN         NaN
# 4       NaN                  NaN          NaN         NaN         NaN
#
#   Acquisitions ID  API
# 0             NaN  NaN
# 1             NaN  NaN
# 2             NaN  NaN
# 3             NaN  NaN
# 4             NaN  NaN
#
# [5 rows x 30 columns]

# %%
all
# Out:
#          company_name                              company_category_list  \
# 0            #waywire           Entertainment|News|Politics|Social Media
# 1               (RED)                                         Nonprofits
# 2      (fluff)Friends                                                NaN
# 3                 .CO                     Curated Web|Domains|Registrars
# 4          .vantronix           Cloud Security|Network Security|Security
# ...               ...                                                ...
# 19009           zurvu           Internet|Online Reservations|Restaurants
# 19010          zuuka!          Apps|Entertainment|Kids|Mobile|Publishing
# 19011        zynamics                                           Security
# 19012        µTorrent                                           Software
# 19013        Übermind  Business Services|Consumer Internet|Content|Cr...
#
#       company_country_code company_state_code company_region   company_city  \
# 0                      USA                 NY  New York City       New York
# 1                      USA                 NY  New York City       New York
# 2                      NaN                NaN            NaN            NaN
# 3                      USA                 FL          Miami          Miami
# 4                      DEU                  6        Hanover        Hanover
# ...                    ...                ...            ...            ...
# 19009                  USA                 NY  New York City       New York
# 19010                  USA                 CA  Santa Barbara  Santa Barbara
# 19011                  DEU                  7         Bochum         Bochum
# 19012                  USA                 CA    SF Bay Area  San Francisco
# 19013                  USA                 WA        Seattle        Seattle
#
#                       acquirer_name  \
# 0                  Waywire Networks
# 1      Nationstar Mortgage Holdings
# 2       SGN (Social Gaming Network)
# 3                           Neustar
# 4                       Compumatica
# ...                             ...
# 19009                       Reserve
# 19010               Cupcake Digital
# 19011                        Google
# 19012                    BitTorrent
# 19013                      Deloitte
#
#                                   acquirer_category_list  \
# 0                                      Curated Web|Video
# 1                                                Finance
# 2                                                  Games
# 3      Advertising|Analytics|Digital Media|Domains|In...
# 4                                                    NaN
# ...                                                  ...
# 19009  Mobile Payments|Online Reservations|Restaurant...
# 19010                                              Games
# 19011  Blogging Platforms|Email|Information Technolog...
# 19012                         Apps|Peer-to-Peer|Software
# 19013  Advice|Business Services|Consulting|Finance|Hu...
#
#       acquirer_country_code acquirer_state_code  ... Year Founded  \
# 0                       USA                  NY  ...          NaN
# 1                       USA                  TX  ...          NaN
# 2                       USA                  CA  ...          NaN
# 3                       USA                  VA  ...          NaN
# 4                       NaN                 NaN  ...          NaN
# ...                     ...                 ...  ...          ...
# 19009                   USA                  NY  ...          NaN
# 19010                   USA                  NY  ...          NaN
# 19011                   USA                  CA  ...       2004.0
# 19012                   USA                  CA  ...          NaN
# 19013                   USA                  NY  ...          NaN
#
#       Market Categories                                       Address (HQ)  \
# 0                   NaN                                                NaN
# 1                   NaN                                                NaN
# 2                   NaN                                                NaN
# 3                   NaN                                                NaN
# 4                   NaN                                                NaN
# ...                 ...                                                ...
# 19009               NaN                                                NaN
# 19010               NaN                                                NaN
# 19011          Security  Grosse Beck Str 3, Bochum, Nordrhein-Westfalen...
# 19012               NaN                                                NaN
# 19013               NaN                                                NaN
#
#       City (HQ)  State / Region (HQ) Country (HQ)  \
# 0           NaN                  NaN          NaN
# 1           NaN                  NaN          NaN
# 2           NaN                  NaN          NaN
# 3           NaN                  NaN          NaN
# 4           NaN                  NaN          NaN
# ...         ...                  ...          ...
# 19009       NaN                  NaN          NaN
# 19010       NaN                  NaN          NaN
# 19011    Bochum  Nordrhein-Westfalen      Germany
# 19012       NaN                  NaN          NaN
# 19013       NaN                  NaN          NaN
#
#                                              Description Acquired by  \
# 0                                                    NaN         NaN
# 1                                                    NaN         NaN
# 2                                                    NaN         NaN
# 3                                                    NaN         NaN
# 4                                                    NaN         NaN
# ...                                                  ...         ...
# 19009                                                NaN         NaN
# 19010                                                NaN         NaN
# 19011  zynamics builds reverse engineering tools for ...      Google
# 19012                                                NaN         NaN
# 19013                                                NaN         NaN
#
#                         Acquisitions ID  \
# 0                                   NaN
# 1                                   NaN
# 2                                   NaN
# 3                                   NaN
# 4                                   NaN
# ...                                 ...
# 19009                               NaN
# 19010                               NaN
# 19011  Google acquired zynamics in 2011
# 19012                               NaN
# 19013                               NaN
#
#                                                      API
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 19009                                                NaN
# 19010                                                NaN
# 19011  http://api.crunchbase.com/v/2/organization/zyn...
# 19012                                                NaN
# 19013                                                NaN
#
# [19014 rows x 30 columns]

# %%
all=pd.merge(
    all,
    acq_tech,
    left_on="company_name",
    right_on="Company",
    how="outer"
)
